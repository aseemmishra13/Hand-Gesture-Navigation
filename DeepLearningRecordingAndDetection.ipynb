# %% [markdown]
# Code referred from https://medium.com/swlh/hand-gestures-using-webcam-and-cnn-convoluted-neural-network-b02c47b3d5ab

# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='HandGestureDataset6'


labels=['fingerup','fingerdown','thumbsup','thumbsdown','fingerleft','fingerright','ok','closedfist','peace sign','rockon sign','L']

number_of_images=20

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        cv2.putText(frame, f"Recording: {label} Number:{imgnum}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 17
#      15 for label in labels:
#      16     img_path = os.path.join(IMAGE_PATH, label)
# ---> 17     os.makedirs(img_path)
#      18     cap=cv2.VideoCapture(0)
#      19     print('Collecting images for {}'.format(label))
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'HandGestureDataset6/fingerup'

# %%
#!git clone https://github.com/ultralytics/yolov5.git
# !cd yolov5

# %%
import os

os.system("python yolov5/detect.py --weights yolov5/runs/train/yolov5s_results/weights/best20.pt --img 420 --conf 0.7 --source 0")
# Out:
# detect: weights=['yolov5/runs/train/yolov5s_results/weights/best20.pt'], source=0, data=yolov5/data/coco128.yaml, imgsz=[420, 420], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/Users/aseemmishra/Downloads/Untitled': No such file or directory
# YOLOv5 🚀 2024-4-18 Python-3.11.0 torch-2.0.1 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7273488 parameters, 0 gradients
# WARNING ⚠️ --img-size [420, 420] must be multiple of max stride 32, updating to [448, 448]
# 2025-02-21 23:50:28.050 python[85306:3045424] +[IMKClient subclass]: chose IMKClient_Modern
# ...
